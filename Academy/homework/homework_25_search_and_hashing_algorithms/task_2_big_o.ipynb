# %%
import matplotlib.pyplot as plt  # type: ignore

# %%
from random import randint

# %%
def iterative_binary_search(sorted_array, element):
    """
    Modified to calculate the Big O
    """

    big_o_counter = 0 # Big O

    counter = 0
    start = 0
    end = len(sorted_array) - 1
    while counter < len(sorted_array):
        big_o_counter += 1 # Big O
        middle = (start + end) // 2
        if sorted_array[middle] == element:
            return middle, big_o_counter # Big O
        elif sorted_array[middle] < element:
            start = middle + 1
        else:
            end = middle - 1
        counter += 1
    return False

# %%
def recursive_binary_search(elements, element, start=None, end=None, big_o_counter=None):
    """
    Modified to calculate the Big O
    """

    if big_o_counter is None:
        big_o_counter = 0 # Big O
    if start is None:
        start = 0
    if end is None:
        end = len(elements) - 1

    big_o_counter += 1

    if end >= start:
        middle = start + (end - start) // 2
        if elements[middle] == element:
            return middle, big_o_counter # Big O
        elif elements[middle] > element:
            return recursive_binary_search(elements, element, start, middle-1, big_o_counter) # Big O
        else:
            return recursive_binary_search(elements, element, middle + 1, end, big_o_counter) # Big O
    else:
        return False

# %%
def fibonacci_search(elements, element):
    """
    Modified to calculate the Big O
    """

    big_o_counter = 0 # Big O

    length = len(elements)
    eliminated = -1
    fibonacci_2 = 0
    fibonacci_1 = 1
    fibonacci = fibonacci_1 + fibonacci_2
    while fibonacci < length:
        fibonacci_1, fibonacci_2 = fibonacci, fibonacci_1
        fibonacci = fibonacci_1 + fibonacci_2
    while fibonacci > 1:

        big_o_counter += 1 # Big O

        current = min(eliminated + fibonacci_2, length - 1)
        if elements[current] == element:
            return current, big_o_counter # Big O
        elif elements[current] > element:
            fibonacci = fibonacci_2
            fibonacci_1 = fibonacci_1 - fibonacci_2
            fibonacci_2 = fibonacci_2 - fibonacci_1
        else:
            fibonacci = fibonacci_1
            fibonacci_1 = fibonacci_2
            fibonacci_2 = fibonacci - fibonacci_1
            eliminated = current
    return False

# %%
steps = [iterative_binary_search(list(range(length)), length // 2)[1] for length in range(10, 10000, 2)]

# %%
plt.plot(steps)
plt.xlabel('Inputs')
plt.ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %%
steps = [recursive_binary_search(list(range(length)), length // 2)[1] for length in range(10, 10000, 2)]

plt.plot(steps)
plt.xlabel('Inputs')
plt.ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %%
steps = [fibonacci_search(list(range(length)), length // 2)[1] for length in range(10, 10000, 2)]

plt.plot(steps)
plt.xlabel('Inputs')
plt.ylabel('Steps')
# Out:
# Text(0, 0.5, 'Steps')

# %%
itera = []
recurs = []
fibo = []

itera = [iterative_binary_search(list(range(length)), length // 2)[1] for length in range(10, 10000, 2)]
recurs = [recursive_binary_search(list(range(length)), length // 2)[1] for length in range(10, 10000, 2)]
fibo = [fibonacci_search(list(range(length)), length // 2)[1] for length in range(10, 10000, 2)]

# %%
print('Для знаходження середнього числа:')
print(f'Середня кількість кроків для "iterative binary search": {round(sum(itera)/len(itera), 3)}')
print(f'Середня кількість кроків для "recursive binary search": {round(sum(recurs)/len(recurs), 3)}')
print(f'Середня кількість кроків для "fibonacci search": {round(sum(fibo)/len(fibo), 3)}')
# Out:
# Для знаходження середнього числа:
# Середня кількість кроків для "iterative binary search": 11.374
# Середня кількість кроків для "recursive binary search": 11.374
# Середня кількість кроків для "fibonacci search": 11.537

# %%
fig, ax = plt.subplots()

ax.plot(list(range(10, 10000, 2)) , fibo, color='green', linewidth=1)
ax.plot(list(range(10, 10000, 2)), itera, color='blue', linewidth=20)
ax.plot(list(range(10, 10000, 2)), recurs, color='red', linewidth=2)

plt.show()

# %%
itera = []
recurs = []
fibo = []

itera = [iterative_binary_search(list(range(length)), randint(0, length-1))[1] for length in range(10, 10000)]
recurs = [recursive_binary_search(list(range(length)), randint(0, length-1))[1] for length in range(10, 10000)]
fibo = [fibonacci_search(list(range(length)), randint(0, length-1))[1] for length in range(10, 10000)]

# %%
print('Для знаходження випадкового числа:')
print(f'Середня кількість кроків для "iterative binary search": {round(sum(itera)/len(itera), 3)}')
print(f'Середня кількість кроків для "recursive binary search": {round(sum(recurs)/len(recurs), 3)}')
print(f'Середня кількість кроків для"fibonacci search": {round(sum(fibo)/len(fibo), 3)}')
# Out:
# Для знаходження випадкового числа:
# Середня кількість кроків для "iterative binary search": 10.892
# Середня кількість кроків для "recursive binary search": 10.915
# Середня кількість кроків для"fibonacci search": 11.477

# %%
fig, ax = plt.subplots()

ax.plot(list(range(10, 10000)), fibo, color='green', linewidth=1)
ax.plot(list(range(10, 10000)), itera, color='blue', linewidth=5)
ax.plot(list(range(10, 10000)), recurs, color='red', linewidth=2)

plt.show()

# %%
itera = []
recurs = []
fibo = []

itera = [iterative_binary_search(list(range(length)), length // 10)[1] for length in range(10, 10000)]
recurs = [recursive_binary_search(list(range(length)), length // 10)[1] for length in range(10, 10000)]
fibo = [fibonacci_search(list(range(length)), length // 10)[1] for length in range(10, 10000)]

# %%
print('Для знаходження числа на початку колекції:')
print(f'Середня кількість кроків для "iterative binary search": {round(sum(itera)/len(itera), 3)}')
print(f'Середня кількість кроків для "recursive binary search": {round(sum(recurs)/len(recurs), 3)}')
print(f'Середня кількість кроків для "fibonacci search": {round(sum(fibo)/len(fibo), 3)}')
# Out:
# Для знаходження числа на початку колекції:
# Середня кількість кроків для "iterative binary search": 11.234
# Середня кількість кроків для "recursive binary search": 11.234
# Середня кількість кроків для "fibonacci search": 10.768

# %%
fig, ax = plt.subplots()

ax.plot(list(range(10, 10000)), fibo, color='green', linewidth=1)
ax.plot(list(range(10, 10000)), itera, color='blue', linewidth=10)
ax.plot(list(range(10, 10000)), recurs, color='red', linewidth=2)

plt.show()

# %%
itera = []
recurs = []
fibo = []

itera = [iterative_binary_search(list(range(length)), 9 * length // 10)[1] for length in range(10, 10000)]
recurs = [recursive_binary_search(list(range(length)), 9 * length // 10)[1] for length in range(10, 10000)]
fibo = [fibonacci_search(list(range(length)), 9 * length // 10)[1] for length in range(10, 10000)]

# %%
print('Для знаходження числа наприкінці колекції:')
print(f'Середня кількість кроків для "iterative binary search": {round(sum(itera)/len(itera), 3)}')
print(f'Середня кількість кроків для "recursive binary search": {round(sum(recurs)/len(recurs), 3)}')
print(f'Середня кількість кроків для "fibonacci search": {round(sum(fibo)/len(fibo), 3)}')
# Out:
# Для знаходження числа наприкінці колекції:
# Середня кількість кроків для "iterative binary search": 11.138
# Середня кількість кроків для "recursive binary search": 11.138
# Середня кількість кроків для "fibonacci search": 12.001

# %%
fig, ax = plt.subplots()

ax.plot(list(range(10, 10000)), fibo, color='green', linewidth=1)
ax.plot(list(range(10, 10000)), itera, color='blue', linewidth=10)
ax.plot(list(range(10, 10000)), recurs, color='red', linewidth=2)

plt.show()
